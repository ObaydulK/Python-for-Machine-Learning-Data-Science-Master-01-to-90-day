# %%
import numpy as np
import pandas as pd

# %%
email = 'jose@email.com'

# %%
email.split('@')
# Out:
# ['jose', 'email.com']

# %%
name = pd.Series(['andreo', 'bobo', 'claire', 'david', '5'])

# %%
name
# Out:
# 0    andreo
# 1      bobo
# 2    claire
# 3     david
# 4         5
# dtype: object

# %%
name.str.upper()
# Out:
# 0    ANDREO
# 1      BOBO
# 2    CLAIRE
# 3     DAVID
# 4         5
# dtype: object

# %%
name.str.isdigit()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# dtype: bool

# %%
that = 'goog, appl, amzn'

# %%
that.split(',')[2]
# Out:
# ' amzn'
