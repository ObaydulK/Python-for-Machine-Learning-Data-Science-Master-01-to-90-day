# %%
import numpy as np
import pandas as pd

# %%
pd.Series
# Out:
# pandas.core.series.Series

# %%
myindex= ['usa', 'thai', 'paragua']
mydata = [ 112, 3312, 5432]

# %%
mysr = pd.Series(data = mydata)

# %%
mysr
# Out:
# 0     112
# 1    3312
# 2    5432
# dtype: int64

# %%
mysr[0]
# Out:
# np.int64(112)

# %%
myindex[0]
# Out:
# 'usa'

# %%
mys = pd.Series(myindex , mydata)

# %%
mys
# Out:
# 112         usa
# 3312       thai
# 5432    paragua
# dtype: object

# %%
ages = {'rifat': 4, 'Frank':10, 'Spike':5}

# %%
pd.Series(ages)
# Out:
# rifat     4
# Frank    10
# Spike     5
# dtype: int64
