# %%
print('hello')
# Out:
# hello

# %%
type(1)
# Out:
# int

# %%
1+1
# Out:
# 2

# %%
1*3
# Out:
# 3

# %%
2**4
# Out:
# 16

# %%
4%2
# Out:
# 0

# %%
5%2
# Out:
# 1

# %%
2+3+5+5
# Out:
# 15

# %%
(2*3) + (5+4)
# Out:
# 15

# %%
x=1
y=3
x*y
# Out:
# 3

# %%
"i Don't Like that"
# Out:
# "i Don't Like that"

# %%
print ("my name is {}, and Number {} ".format('Obaydul', 22))
# Out:
# my name is Obaydul, and Number 22

# %%
thislist = ['a', 'b', 'c']

# %%
thislist[1]
# Out:
# 'b'

# %%
thislist.append('look')

# %%
print(thislist)
# Out:
# ['a', 'b', 'c', 'look']

# %%
dis = {'item1': 'huny', 'item2':'bliss'}

# %%
dis['item1']
# Out:
# 'huny'

# %%
dis['item2']
# Out:
# 'bliss'

# %%
print(dis)
# Out:
# {'item1': 'huny', 'item2': 'bliss'}
