# %%
def my_func(name):
    print('hello')
my_func('')
# Out:
# hello

# %%
def my_func(name):
    print('hello'+ name)
my_func(' Obaydul_Kuasha')
# Out:
# hello Obaydul_Kuasha

# %%
def my_func(name = ' Kuasha'):
    print('hello'+ name)
my_func()
# Out:
# hello Kuasha

# %%
def square(x):
    return x**2
result = square(4)
result
# Out:
# 16

# %%
def times(var):
    return var*2
times(30)
# Out:
# 60

# %%
lambda var:var*2
# Out:
# <function __main__.<lambda>(var)>

# %%
str = 'Hello my name obaydul_Kuasha'
str.lower()
# Out:
# 'hello my name obaydul_kuasha'

# %%
str.upper()
# Out:
# 'HELLO MY NAME OBAYDUL_KUASHA'

# %%
str.split()
# Out:
# ['Hello', 'my', 'name', 'obaydul_Kuasha']

# %%
tweet = 'Hello #sports not bad'
tweet.split()
# Out:
# ['Hello', '#sports', 'not', 'bad']

# %%
tweet.split('#') [-1]
# Out:
# 'sports not bad'
